# %%
import pandas as pd

file_path = '/content/malayalam_legal_loanwords_dataset (2).xlsx'
df = pd.read_excel(file_path)
display(df.head())
# Out:
#         document_id sentence_id                                  word  \
# 0  DOC_CIRCULAR_001   sent_0001                    à´¨à´Ÿà´¤àµà´¤à´¿
# 1  DOC_CIRCULAR_001   sent_0001  à´¡àµ‹à´•àµà´¯àµà´®àµ†à´¨àµà´±àµ
# 2  DOC_CIRCULAR_001   sent_0001                       à´µà´•àµà´«àµ
# 3  DOC_CIRCULAR_001   sent_0001                 à´…à´¨àµà´¯à´¾à´¯à´‚
# 4  DOC_CIRCULAR_001   sent_0001                       à´¨à´Ÿà´ªà´Ÿà´¿
#
#    is_loanword origin_language       original_form grammatical_function  \
# 0        False          Native                 NaN                 VERB
# 1         True         English            document                 NOUN
# 2         True         Persian              ÙˆÙ‚Ù                 NOUN
# 3         True        Sanskrit  à¤…à¤¨à¥à¤¯à¤¾à¤¯                 NOUN
# 4        False          Native                 NaN                 NOUN
#
#   morphophonemic_changes  integration_level            semantic_domain  \
# ...

# %%
df.columns
# Out:
# Index(['document_id', 'sentence_id', 'word', 'is_loanword', 'origin_language',
#        'original_form', 'grammatical_function', 'morphophonemic_changes',
#        'integration_level', 'semantic_domain', 'native_equivalents'],
#       dtype='object')

# %%
df["is_loanword"].value_counts()
# Out:
# is_loanword
# False    792
# True     244
# Name: count, dtype: int64

# %%
loanwords = df[df["is_loanword"] == True]

# %%
loanwords = df[df["is_loanword"] == "Yes"]

# %%
print("Total entries:", len(df))
print("Loanwords:", len(loanwords))
# Out:
# Total entries: 1036
# Loanwords: 0

# %%
loanwords["origin_language"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
lang_counts = loanwords["origin_language"].value_counts()
lang_counts
# Out:
# Series([], Name: count, dtype: int64)

# %%
lang_counts.to_csv("loanwords_by_origin_language.csv")

# %%
lang_counts.plot(kind="bar", title="Loanwords by Source Language")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2414844835.py in <cell line: 0>()
# ----> 1 lang_counts.plot(kind="bar", title="Loanwords by Source Language")
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
loanwords = df[df["is_loanword"] == True]

# %%
len(loanwords)
# Out:
# 244

# %%
lang_counts = loanwords["origin_language"].value_counts()
lang_counts
# Out:
# origin_language
# Persian     56
# Sanskrit    50
# Greek       49
# English     45
# Tamil       44
# Name: count, dtype: int64

# %%
lang_counts.plot(kind="bar", title="Loanwords by Source Language")
# Out:
# <Axes: title={'center': 'Loanwords by Source Language'}, xlabel='origin_language'>

# %%
lang_counts.to_csv("loanwords_by_origin_language.csv")

# %%
integration_counts = loanwords["integration_level"].value_counts()
integration_counts
# Out:
# integration_level
# 4.0    141
# 5.0     93
# 3.0     10
# Name: count, dtype: int64

# %%
integration_counts.to_csv("loanwords_by_integration_level.csv")

# %%
# Loanword Analysis in Legal Malayalam
# This notebook analyzes annotated legal Malayalam data
# to study the distribution and characteristics of loanwords
# using basic Python and pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the annotated loanword dataset
df = pd.read_excel("/content/malayalam_legal_loanwords_dataset")

# Preview the data
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1388641894.py in <cell line: 0>()
#       1 # Load the annotated loanword dataset
# ----> 2 df = pd.read_excel("/content/malayalam_legal_loanwords_dataset")
#       3
#       4 # Preview the data
#       5 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df = pd.read_excel("/content/malayalam_legal_loanwords_dataset (2).xlsx")

# %%
df.head()
# Out:
#         document_id sentence_id                                  word  \
# 0  DOC_CIRCULAR_001   sent_0001                    à´¨à´Ÿà´¤àµà´¤à´¿
# 1  DOC_CIRCULAR_001   sent_0001  à´¡àµ‹à´•àµà´¯àµà´®àµ†à´¨àµà´±àµ
# 2  DOC_CIRCULAR_001   sent_0001                       à´µà´•àµà´«àµ
# 3  DOC_CIRCULAR_001   sent_0001                 à´…à´¨àµà´¯à´¾à´¯à´‚
# 4  DOC_CIRCULAR_001   sent_0001                       à´¨à´Ÿà´ªà´Ÿà´¿
#
#    is_loanword origin_language       original_form grammatical_function  \
# 0        False          Native                 NaN                 VERB
# 1         True         English            document                 NOUN
# 2         True         Persian              ÙˆÙ‚Ù                 NOUN
# 3         True        Sanskrit  à¤…à¤¨à¥à¤¯à¤¾à¤¯                 NOUN
# 4        False          Native                 NaN                 NOUN
#
#   morphophonemic_changes  integration_level            semantic_domain  \
# ...

# %%
lang_counts = loanwords["origin_language"].value_counts()
lang_counts
# Out:
# origin_language
# Persian     56
# Sanskrit    50
# Greek       49
# English     45
# Tamil       44
# Name: count, dtype: int64

# %%
grammar_counts = loanwords["grammatical_function"].value_counts()
grammar_counts
# Out:
# grammatical_function
# NOUN    244
# Name: count, dtype: int64

# %%
integration_counts = loanwords["integration_level"].value_counts()
integration_counts
# Out:
# integration_level
# 4.0    141
# 5.0     93
# 3.0     10
# Name: count, dtype: int64

# %%
lang_counts.plot(kind="bar", title="Loanwords by Source Language")
plt.show()

grammar_counts.plot(kind="bar", title="Loanwords by Grammatical Function")
plt.show()

# %%
lang_counts.to_csv("loanwords_by_origin_language.csv")
grammar_counts.to_csv("loanwords_by_grammatical_function.csv")
integration_counts.to_csv("loanwords_by_integration_level.csv")
